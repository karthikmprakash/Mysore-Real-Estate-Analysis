# %%
import pandas as pd

# %%
df = pd.read_csv('combined.csv')

# %%
df.head()
# Out:
#                 Location  Beds  Price    Area  PricePerSqft
# 0  1st Stage Vijayanagar     2  120.0  1500.0      0.080000
# 1  1st Stage Vijayanagar     5   68.0  1900.0      0.035789
# 2  1st Stage Vijayanagar     5  250.0  2400.0      0.104167
# 3  1st Stage Vijayanagar     4   45.0  1200.0      0.037500
# 4  1st Stage Vijayanagar     4   25.0   600.0      0.041667

# %%
df['Location'].unique()
# Out:
# array(['1st Stage Vijayanagar', '2nd Stage Vijaynagar',
#        '3rd Stage Vijayanagar', '4th Stage Vijayanagar',
#        'Allanahalli Layout', 'Bannimantap', 'Bogadi', 'Bunnymantap',
#        'Chamarajapuram Mohalla', 'Dattagalli', 'Dattagalli 3rd Stage',
#        'Gayathripuram', 'Gokulam 3rd Stage', 'Hanchya', 'Hebbal',
#        'Hootagalli', 'Hulikere', 'Ittige Gudu', 'J.P Nagar',
#        'Jayalakshmipuram', 'Jayanagar', 'Jss Layout', 'KRS Road',
#        'Kalyanagiri', 'Kesare', 'Kuvempunagar', 'Lakshmipuram',
#        'Mandi Mohalla', 'Mysore', 'N R Mohalla', 'Nanjangud',
#        'Police layout', 'RS Naidu Nagar', 'Rajiv Nagar',
#        'Saraswathipuram', 'Sardar Vallabh Bhai Patel Nagar',
#        'Sathagalli Layout', 'Sharadadevi Nagar', 'Siddharthanagar',
#        'Sriramapura 2nd Stage', 'Srirampura', 'Srirangapatna',
#        'Udayagiri', 'V V Mohalla', 'Vani Vilas Mohalla',
#        'Vidyaranyapuram', 'Vijayanagar', 'Vijaynagar',
# ...

# %%
for i,x in enumerate(df.Location):
    print(x)
    if 'hebbal' in x.lower():
        df['Location'][i] = 'Hebbal'
    elif 'vijay' in x.lower():
        df['Location'][i] = 'Vijayanagar'
    elif 'J P' in x.lower():
        df['Location'][i] = 'JP Nagar'
    elif 'v v' or 'vani' or 'vonti' in x.lower():
        df['Location'][i] = 'VV Mohalla'
    elif 'dattagalli' in x.lower():
        df['Location'][i] = 'Dattagalli'
    else:
        df['Location'][i] = x
# Out:
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# Vijayanagar
# VV Mohalla
# VV Mohalla
# VV Mohalla
# VV Mohalla
# VV Mohalla
# VV Mohalla
# VV Mohalla
# VV Mohalla
# VV Mohalla
# VV Mohalla
# VV Mohalla
# VV Mohalla
# VV Mohalla
# VV Mohalla
# VV Mohalla
# VV Mohalla
# VV Mohalla
# VV Mohalla
# VV Mohalla
# VV Mohalla
# VV Mohalla
# VV Mohalla
# ...

# %%
df['Location'].unique()
# Out:
# array(['Vijayanagar', 'VV Mohalla', 'Hebbal'], dtype=object)

# %%
df
# Out:
#         Location  Beds   Price    Area  PricePerSqft
# 0    Vijayanagar     2  120.00  1500.0      0.080000
# 1    Vijayanagar     5   68.00  1900.0      0.035789
# 2    Vijayanagar     5  250.00  2400.0      0.104167
# 3    Vijayanagar     4   45.00  1200.0      0.037500
# 4    Vijayanagar     4   25.00   600.0      0.041667
# ..           ...   ...     ...     ...           ...
# 588   VV Mohalla     2   63.25  1183.0      0.050000
# 589   VV Mohalla     3   79.16  1116.0      0.070000
# 590   VV Mohalla     3   52.93   967.0      0.050000
# 591   VV Mohalla     3  105.30  1265.0      0.080000
# 592   VV Mohalla     3   96.75  1350.0      0.070000
#
# [593 rows x 5 columns]
